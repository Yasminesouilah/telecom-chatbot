# %% [markdown]
# # Mobilis Telecom - Intent Classification (DistilBERT)
# Improved version with diagnostics, leakage checks, and a confidence fallback for the RAG/LLM pipeline.
#
# **What changed vs. the original notebook:**
# 1. Full classification report + confusion matrix actually printed
# 2. Misclassified examples inspection (see *what* is being confused with *what*)
# 3. Near-duplicate leakage check between train/test (Bitext data is heavily templated)
# 4. Keyword lookup helper to inspect which intent a given word/phrase belongs to
# 5. Confidence-threshold fallback in the inference loop so low-confidence predictions don't get passed blindly to the LLM

# %%
# !nvidia-smi
# Out:
# Thu Aug 13 17:41:24 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 1. Install Required Libraries

# %%
# !pip install -q transformers datasets accelerate evaluate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.5 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from difflib import SequenceMatcher
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from transformers import DistilBertTokenizerFast, DistilBertForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
import evaluate

# %% [markdown]
# ## 3. Load the Dataset

# %%
df = pd.read_csv("hf://datasets/bitext/Bitext-telco-llm-chatbot-training-dataset/bitext-telco-llm-chatbot-training-dataset.csv")
df.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
#                                          instruction           intent  \
# 0  there are charges on my phone bill that i do n...  dispute_invoice
# 1  my internet bill is incorrect, can you help me...  dispute_invoice
# 2              my invoice is not corect challenge it  dispute_invoice
# 3  I don't recognize some charges on my bill, can...  dispute_invoice
# 4       i have to dispute a fucking bill i need help  dispute_invoice
#
#   category    tags                                           response
# 0  BILLING  BCELQZ  If you have noticed discrepancies in your bill...
# 1  BILLING   BCILZ  If there is an issue with your bill and you wo...
# 2  BILLING  BCELQZ  If you find any discrepancies in your invoice ...
# 3  BILLING    BCIL  If you have found charges on your bill that yo...
# 4  BILLING    BCQW  If you believe there is an error on your bill ...

# %% [markdown]
# ## 4. Explore the Dataset

# %%
print(df.shape)
print(df.columns)
print(df.isnull().sum())
print("Exact duplicate rows:", df.duplicated().sum())
print("Number of intents:", df["intent"].nunique())
display(df.head())
# Out:
# (26000, 5)
# Index(['instruction', 'intent', 'category', 'tags', 'response'], dtype='object')
# instruction    0
# intent         0
# category       0
# tags           0
# response       0
# dtype: int64
# Exact duplicate rows: 0
# Number of intents: 26
#                                          instruction           intent  \
# 0  there are charges on my phone bill that i do n...  dispute_invoice
# 1  my internet bill is incorrect, can you help me...  dispute_invoice
# 2              my invoice is not corect challenge it  dispute_invoice
# 3  I don't recognize some charges on my bill, can...  dispute_invoice
# 4       i have to dispute a fucking bill i need help  dispute_invoice
#
#   category    tags                                           response
# 0  BILLING  BCELQZ  If you have noticed discrepancies in your bill...
# 1  BILLING   BCILZ  If there is an issue with your bill and you wo...
# 2  BILLING  BCELQZ  If you find any discrepancies in your invoice ...
# 3  BILLING    BCIL  If you have found charges on your bill that yo...
# 4  BILLING    BCQW  If you believe there is an error on your bill ...

# %% [markdown]
# ## 5. Visualize Intent Distribution

# %%
plt.figure(figsize=(8,8))
sns.countplot(y=df["intent"], order=df["intent"].value_counts().index)
plt.title("Examples per intent")
plt.show()

# %% [markdown]
# ## 6. Keyword Lookup Helper
# Use this **before** you assume a phrase belongs to a given intent. It tells you which intents actually contain a keyword in their training examples, and how many examples support it. If your target word barely appears anywhere, that's very likely why the model is confidently wrong on it.

# %%
def inspect_keyword(keyword, n=15):
    matches = df[df["instruction"].str.contains(keyword, case=False, na=False)]
    print(f'"{keyword}" appears in {len(matches)} training examples\n')
    print("Distribution across intents:")
    print(matches["intent"].value_counts())
    print()
    display(matches[["instruction", "intent"]].head(n))
    return matches

# Example: check how "slow" is represented in the dataset
_ = inspect_keyword("slow")
# Out:
# "slow" appears in 25 training examples
#
# Distribution across intents:
# intent
# report_poor_signal_coverage    25
# Name: count, dtype: int64
#                                             instruction  \
# 3032  my internet is slow id like to repot poor sign...
# 3076  my internet is slow, howcan I report poor sign...
# 3114  my internet is slow, I'd like to complain abou...
# 3167  my internet is slow, how do I report poor sign...
# 3170  my internet is slow i have to complain about p...
# 3205  my internet is slow i need to complain about p...
# 3218  my internet is slow i need to complakn about p...
# 3230  my internet is slow, I need to report poor sig...
# 3254  my internet is slow , I have to complain about...
# 3308  my internet is slow hw do i complain about poo...
# 3339  my internet is slow, I'd likr to complain abou...
# 3369  my internet is slow id like to complain about ...
# 3451  my internet is slow, I'd like to report poor s...
# 3484  my internet is slow i need to report poor sign...
# 3529  my internet is slow, I got to complain about p...
#
#                            intent
# 3032  report_poor_signal_coverage
# 3076  report_poor_signal_coverage
# 3114  report_poor_signal_coverage
# 3167  report_poor_signal_coverage
# 3170  report_poor_signal_coverage
# 3205  report_poor_signal_coverage
# 3218  report_poor_signal_coverage
# 3230  report_poor_signal_coverage
# 3254  report_poor_signal_coverage
# 3308  report_poor_signal_coverage
# 3339  report_poor_signal_coverage
# 3369  report_poor_signal_coverage
# 3451  report_poor_signal_coverage
# 3484  report_poor_signal_coverage
# 3529  report_poor_signal_coverage

# %% [markdown]
# ## 7. Data Cleaning & Label Encoding

# %%
df = df.drop_duplicates().dropna()
df["instruction"] = df["instruction"].str.lower()
labels = sorted(df.intent.unique())
label2id = {l: i for i, l in enumerate(labels)}
id2label = {i: l for l, i in label2id.items()}
df["label"] = df["intent"].map(label2id)
print(f"{len(labels)} intents:", labels)
# Out:
# 26 intents: ['activate_call_management_services', 'activate_phone', 'activate_roaming', 'cancel_plan', 'change_plan', 'change_provider', 'check_cancellation_fee', 'check_excess_data_charges', 'check_mobile_payments', 'check_signal_coverage', 'check_usage', 'customer_service', 'deactivate_call_management_services', 'deactivate_phone', 'dispute_invoice', 'get_compensation', 'human_agent', 'install_internet', 'invoices', 'pay', 'payment_methods', 'report_poor_signal_coverage', 'report_problem', 'schedule_payments', 'set_usage_limits', 'sign_up_for_plan']

# %% [markdown]
# ## 8. Train/Test Split & Tokenization

# %%
# ============================================================
# TRAIN / VALIDATION / TEST SPLIT
# ============================================================
# 80% train, 20% temporary
train_texts, temp_texts, train_labels, temp_labels = train_test_split(
    df["instruction"], df["label"], test_size=0.20, random_state=42, stratify=df["label"]
)

# Split the temporary 20% into 10% validation + 10% test
val_texts, test_texts, val_labels, test_labels = train_test_split(
    temp_texts, temp_labels, test_size=0.50, random_state=42, stratify=temp_labels
)

print(f"Train:      {len(train_texts)}")
print(f"Validation: {len(val_texts)}")
print(f"Test:       {len(test_texts)}")

tokenizer = DistilBertTokenizerFast.from_pretrained("distilbert-base-uncased")

train_enc = tokenizer(list(train_texts), truncation=True, padding=True, max_length=64)
val_enc = tokenizer(list(val_texts), truncation=True, padding=True, max_length=64)
test_enc = tokenizer(list(test_texts), truncation=True, padding=True, max_length=64)

train_ds = Dataset.from_dict(train_enc).add_column("labels", list(train_labels))
val_ds = Dataset.from_dict(val_enc).add_column("labels", list(val_labels))
test_ds = Dataset.from_dict(test_enc).add_column("labels", list(test_labels))
# Out:
# Train:      20800
# Validation: 2600
# Test:       2600
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %% [markdown]
# ## 9. Leakage Check: Near-Duplicate Templates Across Train/Test
# Bitext data is heavily templated, so exact `drop_duplicates()` isn't enough — many near-identical sentences (same template, one word swapped) can end up split across train and test. That inflates your eval accuracy without reflecting real generalization. This cell samples pairs and estimates how big the problem is.

# %%
def near_duplicate_rate(train_texts, test_texts, sample_train=800, sample_test=80, threshold=0.9, seed=1):
    tr_sample = pd.Series(train_texts).sample(min(sample_train, len(train_texts)), random_state=seed).tolist()
    te_sample = pd.Series(test_texts).sample(min(sample_test, len(test_texts)), random_state=seed).tolist()
    near_dupes = 0
    for t in te_sample:
        if any(SequenceMatcher(None, t, tr).ratio() > threshold for tr in tr_sample):
            near_dupes += 1
    rate = near_dupes / len(te_sample)
    print(f"{near_dupes}/{len(te_sample)} sampled test examples ({rate:.0%}) are near-duplicates "
          f"(similarity > {threshold}) of a sampled train example.")
    print("If this is high, your test accuracy below is optimistic and won't reflect real-world phrasing.")
    return rate

_ = near_duplicate_rate(train_texts, test_texts)
# Out:
# 8/80 sampled test examples (10%) are near-duplicates (similarity > 0.9) of a sampled train example.
# If this is high, your test accuracy below is optimistic and won't reflect real-world phrasing.

# %% [markdown]
# ## 10. Build and Train DistilBERT

# %%
model = DistilBertForSequenceClassification.from_pretrained(
    "distilbert-base-uncased", num_labels=len(labels), id2label=id2label, label2id=label2id
)

acc = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels_ = eval_pred
    preds = np.argmax(logits, axis=-1)
    return acc.compute(predictions=preds, references=labels_)

args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=4,
    weight_decay=0.01,
    load_best_model_at_end=True,
)

# eval_dataset is the VALIDATION set, not the test set -- this is what
# load_best_model_at_end uses to pick the checkpoint. The test set below
# is never seen until final evaluation.
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    compute_metrics=compute_metrics,
)

trainer.train()
trainer.evaluate()  # validation performance, used only for checkpoint selection
# Out:
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  268MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# [transformers] DistilBertForSequenceClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_layer_norm.bias   | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_projector.bias    | UNEXPECTED |
# pre_classifier.weight   | MISSING    |
# classifier.weight       | MISSING    |
# pre_classifier.bias     | MISSING    |
# classifier.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Downloading builder script: 0.00B [00:00, ?B/s]
#     <div>
#
#       <progress value='5200' max='5200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5200/5200 05:01, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.036211</td>
#       <td>0.013530</td>
#       <td>0.997692</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.002416</td>
#       <td>0.001572</td>
#       <td>0.999615</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.001172</td>
#       <td>0.000474</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000634</td>
#       <td>0.000335</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='163' max='163' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [163/163 00:02]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Epoch</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.000634</td>
#       <td>0.000335</td>
#       <td>4</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# {'eval_loss': 0.00033493770752102137, 'eval_accuracy': 1.0}

# %% [markdown]
# ## 11. Evaluate the Model (full report + confusion matrix)

# %%
# Final, untouched-until-now TEST set evaluation.
# This is the number that actually answers: "how well does the
# selected model perform on data it never influenced?"
preds = np.argmax(trainer.predict(test_ds).predictions, axis=1)

print(classification_report(test_labels, preds, target_names=labels))

cm = confusion_matrix(test_labels, preds)
plt.figure(figsize=(12,10))
sns.heatmap(cm, xticklabels=labels, yticklabels=labels, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()
# Out:
#                                      precision    recall  f1-score   support
#
#   activate_call_management_services       1.00      0.99      0.99       100
#                      activate_phone       1.00      1.00      1.00       100
#                    activate_roaming       1.00      1.00      1.00       100
#                         cancel_plan       1.00      1.00      1.00       100
#                         change_plan       1.00      1.00      1.00       100
#                     change_provider       1.00      1.00      1.00       100
#              check_cancellation_fee       1.00      1.00      1.00       100
#           check_excess_data_charges       1.00      1.00      1.00       100
#               check_mobile_payments       1.00      1.00      1.00       100
#               check_signal_coverage       1.00      1.00      1.00       100
#                         check_usage       1.00      1.00      1.00       100
#                    customer_service       1.00      1.00      1.00       100
# deactivate_call_management_services       0.99      1.00      1.00       100
#                    deactivate_phone       1.00      1.00      1.00       100
#                     dispute_invoice       1.00      1.00      1.00       100
#                    get_compensation       1.00      1.00      1.00       100
#                         human_agent       1.00      1.00      1.00       100
#                    install_internet       1.00      1.00      1.00       100
#                            invoices       1.00      1.00      1.00       100
#                                 pay       1.00      1.00      1.00       100
#                     payment_methods       1.00      1.00      1.00       100
#         report_poor_signal_coverage       1.00      1.00      1.00       100
#                      report_problem       1.00      1.00      1.00       100
#                   schedule_payments       1.00      1.00      1.00       100
#                    set_usage_limits       1.00      1.00      1.00       100
#                    sign_up_for_plan       1.00      1.00      1.00       100
#
#                            accuracy                           1.00      2600
#                           macro avg       1.00      1.00      1.00      2600
#                        weighted avg       1.00      1.00      1.00      2600

# %% [markdown]
# ## 12. Inspect Misclassified Examples
# Don't just trust the accuracy number — read what's actually being confused. This tells you whether errors are genuine ambiguity (two reasonable intents) or the model just hasn't learned a pattern.

# %%
test_texts_reset = test_texts.reset_index(drop=True)
test_labels_reset = test_labels.reset_index(drop=True)

wrong_idx = np.where(preds != test_labels_reset.values)[0]
print(f"{len(wrong_idx)} / {len(test_labels_reset)} test examples misclassified\n")

for i in wrong_idx[:20]:
    print(f"TEXT: {test_texts_reset[i]}")
    print(f"TRUE: {labels[test_labels_reset[i]]}  |  PRED: {labels[preds[i]]}")
    print("-" * 60)
# Out:
# 1 / 2600 test examples misclassified
#
# TEXT: i want to turn no voicemail, how can i do it?
# TRUE: activate_call_management_services  |  PRED: deactivate_call_management_services
# ------------------------------------------------------------

# %% [markdown]
# ## 13. Save the Model

# %%
trainer.save_model("mobilis_intent_model")
tokenizer.save_pretrained("mobilis_intent_model")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ('mobilis_intent_model/tokenizer_config.json',
#  'mobilis_intent_model/tokenizer.json')

# %% [markdown]
# ## 14. Inference with Confidence Fallback
# Key change from the original: if the model isn't confident, don't hand a wrong intent label to the downstream LLM/RAG step. Fall back to `"unknown"` and let the next stage handle it generically (e.g. broader retrieval, or ask a clarifying question).

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

shutil.copytree(
    "/content/mobilis_intent_model",
    "/content/drive/MyDrive/mobilis_intent_model",
    dirs_exist_ok=True
)

print("Model copied to Google Drive")
# Out:
# Model copied to Google Drive

# %%
from transformers import pipeline

classifier = pipeline(
    "text-classification",
    model="./mobilis_intent_model",
    tokenizer="./mobilis_intent_model",
    top_k=5
)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
test_sentences = [
    "I want to install internet at my home.",
    "My internet connection is not working.",
    "My internet is very slow.",
    "I forgot my password.",
    "I want to cancel my internet subscription.",
    "I don't recognize a charge on my bill.",
    "Why is my bill higher than usual?",
    "I want to know how much data I have used.",
    "I want to change my mobile plan.",
    "I need a technician to come to my house.",
    "My SIM card stopped working.",
    "Where is the nearest Mobilis store?",
]

for sentence in test_sentences:

    result = classifier(sentence.lower())[0]

    print("\n" + "=" * 70)
    print("Question:", sentence)

    for prediction in result:
        print(
            f"{prediction['label']:30s} "
            f"{prediction['score']:.4f}"
        )
# Out:
# ======================================================================
# Question: I want to install internet at my home.
# install_internet               0.9997
# activate_roaming               0.0000
# activate_phone                 0.0000
# sign_up_for_plan               0.0000
# change_provider                0.0000
#
# ======================================================================
# Question: My internet connection is not working.
# cancel_plan                    0.9510
# activate_roaming               0.0267
# report_poor_signal_coverage    0.0047
# install_internet               0.0035
# change_provider                0.0029
#
# ======================================================================
# Question: My internet is very slow.
# cancel_plan                    0.4235
# activate_roaming               0.2998
# install_internet               0.0617
# change_provider                0.0524
# deactivate_call_management_services 0.0178
#
# ======================================================================
# Question: I forgot my password.
# check_usage                    0.6908
# invoices                       0.2523
# check_cancellation_fee         0.0081
# change_plan                    0.0071
# cancel_plan                    0.0071
#
# ======================================================================
# Question: I want to cancel my internet subscription.
# cancel_plan                    0.9995
# report_poor_signal_coverage    0.0001
# set_usage_limits               0.0000
# activate_roaming               0.0000
# check_cancellation_fee         0.0000
#
# ======================================================================
# Question: I don't recognize a charge on my bill.
# dispute_invoice                0.9996
# get_compensation               0.0000
# invoices                       0.0000
# check_excess_data_charges      0.0000
# set_usage_limits               0.0000
#
# ======================================================================
# Question: Why is my bill higher than usual?
# invoices                       0.6127
# set_usage_limits               0.3267
# dispute_invoice                0.0477
# check_mobile_payments          0.0020
# check_cancellation_fee         0.0017
#
# ======================================================================
# Question: I want to know how much data I have used.
# check_usage                    0.9857
# check_excess_data_charges      0.0099
# check_signal_coverage          0.0008
# invoices                       0.0003
# activate_phone                 0.0003
#
# ======================================================================
# Question: I want to change my mobile plan.
# change_plan                    0.9997
# cancel_plan                    0.0000
# check_usage                    0.0000
# activate_call_management_services 0.0000
# sign_up_for_plan               0.0000
#
# ======================================================================
# Question: I need a technician to come to my house.
# human_agent                    0.5452
# sign_up_for_plan               0.1423
# pay                            0.0892
# customer_service               0.0438
# install_internet               0.0381
#
# ======================================================================
# Question: My SIM card stopped working.
# cancel_plan                    0.9850
# activate_roaming               0.0033
# invoices                       0.0020
# payment_methods                0.0013
# activate_phone                 0.0010
#
# ======================================================================
# Question: Where is the nearest Mobilis store?
# customer_service               0.4937
# install_internet               0.2676
# check_signal_coverage          0.0868
# change_provider                0.0246
# payment_methods                0.0239
